# %% [markdown]
# # Python Variables Practice (Assignment 1)
#
# **Topics Covered:**
# - Variable creation
# - int, float, str, bool data types
# - Printing variables
# - f-strings

# %% [markdown]
# ## Section 1: Variable Creation & Printing

# %% [markdown]
# ### Question 1
# Create a variable to store your **age** and print it.

# %%
# write your answer

age =35

print(age)

# %% [markdown]
# ### Question 2
# Create a variable to store the **price of a notebook** (can be a decimal value) and print it.

# %%
book=250.25
print(type(book),book)
# Out:
# <class 'float'> 250.25

# %% [markdown]
# ### Question 3
# Create a variable to store your **first name** and print it.

# %%
name="rohit maurya"
print(name)
# Out:
# rohit maurya

# %% [markdown]
# ### Question 4
# Create a variable to store whether you have **completed today’s class** (True/False) and print it.

# %%
aaj_ki_class_complete=True
print(aaj_ki_class_complete)
# Out:
# True

# %% [markdown]
# ### Question 5
# Create two variables:
# - one to store the **number of classes attended**
# - one to store the **average rating** (float)
# Print both.

# %%
classes_attended = 25
average_rating = 4.5
print("Classes Attended:", classes_attended)
print("Average Rating:", average_rating)
# Out:
# Classes Attended: 25
# Average Rating: 4.5

# %% [markdown]
# ## Section 2: Printing using f-strings

# %% [markdown]
# ### Question 6
# Create variables for **name** and **age** and print:
# > My name is Rahul and I am 22 years old.

# %%
name="rohit maurya"
age=21
print(f" my name if {name} and i am {age} years old")
# Out:
#  my name if rohit maurya and i am 21 years old

# %% [markdown]
# ### Question 7
# Create variables for **item name** and **price** and print:
# > The price of Pen is 10.5 rupees.

# %%
product="pen"
price=10.5
print(f" the price of {product} is {price} rupees.")
# Out:
#  the price of pen is 10.5 rupees.

# %% [markdown]
# ### Question 8
# Create variables for **batch name** and **class completed status** and print:
# > Batch DA10 class completed status is True.

# %%
cl_name="DA10 CLASS"
complete="true"
print(f"batch {cl_name} completed status is {complete}")
# Out:
# batch DA10 CLASS completed status is true
